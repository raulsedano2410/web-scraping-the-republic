# %%
import csv  # Para leer y escribir archivos CSV
import os  # Para operaciones en el sistema de archivos como verificar rutas
import requests  # Para hacer solicitudes HTTP
from bs4 import BeautifulSoup  # Para el análisis HTML
import time  # Para pausas entre solicitudes
from lxml import etree

# %%
# Archivo para almacenar las URL visitadas
visited_urls_file = "visited_urls.csv"

# Archivo CSV que contiene las URL de inicio para rastrear
start_urls_csv = "mafia_nigeriana_2009-02-24_2024-01-01.csv"

# Clase Spider para manejar el rastreo de artículos de noticias
class MySpider:
    def __init__(self):
        pass

    # Método para iniciar las solicitudes
    def start_requests(self):

        # Verifica si existe el archivo de URL visitadas para ver si es la primera ejecución o una continuación después de un fallo
        if os.path.exists(visited_urls_file):
            # Abre el archivo y crea un conjunto de URL ya visitadas
            with open(visited_urls_file) as f:
                reader = csv.reader(f)
                visited_urls = {row[0] for row in reader if row}
        else:
            # Si el archivo no existe, es la primera ejecución
            visited_urls = set()

        # Abre el CSV de URL de inicio y itera a través de él
        with open(start_urls_csv, "r", newline="") as file:
            reader = csv.DictReader(file)

            iteration = 1

            for row in reader:
                url = row["URL"]

                print(f"Iteración número {iteration}")

                # Verifica la URL contra las ya visitadas
                if url not in visited_urls:
                    visited_urls.add(url)

                    # Hace la solicitud HTTP
                    response = requests.get(url)
                    if response.status_code == 200:
                        # Llama al método parse para manejar la respuesta
                        self.parse(response)
                    elif response.status_code == 403:

                        print('status is 403\n' * 3)

                        print('start the 4 minute wait')

                        for i in range(1,5):
                            time.sleep(60)
                            print(f'{i} minutes have passed')
                iteration += 1


    # Método que maneja el análisis de la respuesta
    def parse(self, response):
        # Analiza el contenido HTML
        soup = BeautifulSoup(response.content, "html.parser")

        # Encuentra todos los elementos de artículo en la página
        articles = soup.find_all("article")

        # Lista para almacenar los datos extraídos del artículo
        article_data = []

        for article in articles:
            # Obtiene el HTML interno de la etiqueta de anclaje del título
            anchor_html = article.find("h1").find("a")

            # Extrae el texto limpio del título
            title = anchor_html.get_text(separator=" ", strip=True)

            # Extrae el enlace del artículo
            link = anchor_html["href"]

            # +++Extrae la fecha de publicación+++

            # Encuentra el elemento <aside>
            aside_element = article.find("aside").find_all("a")

            date = aside_element[-1].get_text(separator=" ", strip=True)



            # +++fin de extraer la fecha de publicación+++

            # Agrega los datos del artículo a la lista
            article_data.append(
                {"title": title, "link": link, "date": date, "page_url": response.url}
            )

        # Escribe los datos extraídos del artículo en el archivo CSV
        with open("output_test.csv", "a", newline="", encoding="utf-8") as file:
            writer = csv.DictWriter(
                file, fieldnames=["title", "link", "date", "page_url"]
            )

            # Escribe el encabezado si el archivo está vacío
            if os.stat("output_test.csv").st_size == 0:
                writer.writeheader()

            # Escribe una fila para cada dato del artículo
            for data in article_data:
                writer.writerow(data)

        # Agrega la URL al archivo de visitados
        with open(visited_urls_file, "a", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow([response.url])

    # Método llamado cuando se cierra el Spider
    def closed(self, reason):
        # Registra la razón del cierre del spider
        print("Spider cerrado:", reason)

    # Método para manejar excepciones de proceso
    def process_exception(self, request, exception, spider):
        if isinstance(exception, requests.exceptions.HTTPError) and exception.response.status_code == 403:
            # Registra el error 403
            print(f"Recibido error 403 en {request.url}")

            # Espera 6 minutos antes de volver a intentar la solicitud
            print("Esperando 6 minutos antes de volver a intentar la solicitud...")
            time.sleep(360)
            return requests.get(request.url)

# Instancia del Spider
spider = MySpider()
# Inicia las solicitudes
spider.start_requests()
# Out:
# Iteración número 1
# Iteración número 2
# Iteración número 3
# Iteración número 4
# Iteración número 5
# Iteración número 6
# Iteración número 7
# Iteración número 8
# Iteración número 9
# Iteración número 10
# Iteración número 11
# Iteración número 12
# Iteración número 13
# Iteración número 14
# Iteración número 15
# Iteración número 16
# Iteración número 17
# Iteración número 18
# Iteración número 19
# Iteración número 20
# Iteración número 21
# Iteración número 22
# Iteración número 23
# Iteración número 24
# Iteración número 25
# Iteración número 26
# Iteración número 27
# Iteración número 28
# Iteración número 29
# Iteración número 30
# Iteración número 31
# Iteración número 32
# Iteración número 33
# Iteración número 34
# Iteración número 35
# Iteración número 36
# Iteración número 37
# Iteración número 38
# Iteración número 39
# Iteración número 40
# Iteración número 41
# Iteración número 42
# Iteración número 43
# Iteración número 44
# Iteración número 45
# Iteración número 46
# Iteración número 47
# Iteración número 48
# Iteración número 49
# Iteración número 50
# Iteración número 51
# Iteración número 52
# Iteración número 53
# Iteración número 54
# Iteración número 55
# Iteración número 56
# Iteración número 57
# Iteración número 58
# Iteración número 59
# Iteración número 60
# Iteración número 61
# Iteración número 62
# Iteración número 63
# Iteración número 64
# Iteración número 65
# Iteración número 66
# Iteración número 67
# Iteración número 68
# Iteración número 69
# Iteración número 70
# Iteración número 71
# Iteración número 72
# Iteración número 73
# Iteración número 74
# Iteración número 75
# Iteración número 76
# Iteración número 77
# Iteración número 78
# Iteración número 79
# Iteración número 80
# Iteración número 81
# Iteración número 82
# Iteración número 83
# Iteración número 84
# Iteración número 85
# Iteración número 86
# Iteración número 87
# Iteración número 88
# Iteración número 89
# Iteración número 90
# Iteración número 91
# Iteración número 92
# Iteración número 93
# Iteración número 94
# Iteración número 95
# Iteración número 96
# Iteración número 97
# Iteración número 98
# Iteración número 99
# Iteración número 100
# Iteración número 101
# Iteración número 102
# Iteración número 103
# Iteración número 104
# Iteración número 105
# Iteración número 106
# Iteración número 107
# Iteración número 108
# Iteración número 109
# Iteración número 110
# Iteración número 111
# Iteración número 112
# Iteración número 113
# Iteración número 114
# Iteración número 115
# Iteración número 116
# Iteración número 117
# Iteración número 118
# Iteración número 119
# Iteración número 120
# Iteración número 121
# Iteración número 122
# Iteración número 123
# Iteración número 124
# Iteración número 125
# Iteración número 126
# Iteración número 127
# Iteración número 128
# Iteración número 129
# Iteración número 130
# Iteración número 131
# Iteración número 132
# Iteración número 133
# Iteración número 134
# Iteración número 135
# Iteración número 136
# Iteración número 137
# Iteración número 138
# Iteración número 139
# Iteración número 140
# Iteración número 141
# Iteración número 142
# Iteración número 143
# Iteración número 144
# Iteración número 145
# Iteración número 146
# Iteración número 147
# Iteración número 148
# Iteración número 149
# Iteración número 150
# Iteración número 151
# Iteración número 152
# Iteración número 153
# Iteración número 154
# Iteración número 155
# Iteración número 156
# Iteración número 157
# Iteración número 158
# Iteración número 159
# Iteración número 160
# Iteración número 161
# Iteración número 162
# Iteración número 163
# Iteración número 164
# Iteración número 165
# Iteración número 166
# Iteración número 167
# Iteración número 168
# Iteración número 169
# Iteración número 170
# Iteración número 171
# Iteración número 172
# Iteración número 173
# Iteración número 174
# Iteración número 175
# Iteración número 176
# Iteración número 177
# Iteración número 178
# Iteración número 179
# Iteración número 180
# Iteración número 181
# Iteración número 182
# Iteración número 183
# Iteración número 184
# Iteración número 185
# Iteración número 186
# Iteración número 187
# Iteración número 188
# Iteración número 189
# Iteración número 190
# Iteración número 191
# Iteración número 192
# Iteración número 193
# Iteración número 194
# Iteración número 195
# Iteración número 196
# Iteración número 197
# Iteración número 198
# Iteración número 199
# Iteración número 200
# Iteración número 201
# Iteración número 202
# Iteración número 203
# Iteración número 204
# Iteración número 205
# Iteración número 206
# Iteración número 207
# Iteración número 208
# Iteración número 209
# Iteración número 210
# Iteración número 211
# Iteración número 212
# Iteración número 213
# Iteración número 214
# Iteración número 215
# Iteración número 216
# Iteración número 217
# Iteración número 218
# Iteración número 219
# Iteración número 220
# Iteración número 221
# Iteración número 222
# Iteración número 223
# Iteración número 224
# Iteración número 225
# Iteración número 226
# Iteración número 227
# Iteración número 228
# Iteración número 229
# Iteración número 230
# Iteración número 231
# Iteración número 232
# Iteración número 233
# Iteración número 234
# Iteración número 235
# Iteración número 236
# Iteración número 237
# Iteración número 238
# Iteración número 239
# Iteración número 240
# Iteración número 241
# Iteración número 242
# Iteración número 243
# Iteración número 244
# Iteración número 245
# Iteración número 246
# Iteración número 247
# Iteración número 248
# Iteración número 249
# Iteración número 250
# Iteración número 251
# Iteración número 252
# Iteración número 253
# Iteración número 254
# Iteración número 255
# Iteración número 256
# Iteración número 257
# Iteración número 258
# Iteración número 259
# Iteración número 260
# Iteración número 261
# Iteración número 262
# Iteración número 263
# Iteración número 264
# Iteración número 265
# Iteración número 266
# Iteración número 267
# Iteración número 268
# Iteración número 269
# Iteración número 270
# Iteración número 271
# Iteración número 272
# Iteración número 273
# Iteración número 274
# Iteración número 275
# Iteración número 276
# Iteración número 277
# Iteración número 278
# Iteración número 279
# Iteración número 280
# Iteración número 281
# Iteración número 282
# Iteración número 283
# Iteración número 284
# Iteración número 285
# Iteración número 286
# Iteración número 287
# Iteración número 288
# Iteración número 289
# Iteración número 290
# Iteración número 291
# Iteración número 292
# Iteración número 293
# Iteración número 294
# Iteración número 295
# Iteración número 296
# Iteración número 297
# Iteración número 298
# Iteración número 299
# Iteración número 300
# Iteración número 301
# Iteración número 302
# Iteración número 303
# Iteración número 304
# Iteración número 305
# Iteración número 306
# Iteración número 307
# Iteración número 308
# Iteración número 309
# Iteración número 310
# Iteración número 311
# Iteración número 312
# Iteración número 313
# Iteración número 314
# Iteración número 315
# Iteración número 316
# Iteración número 317
# Iteración número 318
# Iteración número 319
# Iteración número 320
# Iteración número 321
# Iteración número 322
# Iteración número 323
# Iteración número 324
# Iteración número 325
# Iteración número 326
# Iteración número 327
# Iteración número 328
# Iteración número 329
# Iteración número 330
# Iteración número 331
# Iteración número 332
# Iteración número 333
# Iteración número 334
# Iteración número 335
# Iteración número 336
# Iteración número 337
# Iteración número 338
# Iteración número 339
# Iteración número 340
# Iteración número 341
# Iteración número 342
# Iteración número 343
# Iteración número 344
# Iteración número 345
# Iteración número 346
# Iteración número 347
# Iteración número 348
# Iteración número 349
# Iteración número 350
# Iteración número 351
# Iteración número 352
# Iteración número 353
# Iteración número 354
# Iteración número 355
# Iteración número 356
# Iteración número 357
# Iteración número 358
# Iteración número 359
# Iteración número 360
# Iteración número 361
# Iteración número 362
# Iteración número 363
# Iteración número 364
# Iteración número 365
# Iteración número 366
# Iteración número 367
# Iteración número 368
# Iteración número 369
# Iteración número 370
# Iteración número 371
# Iteración número 372
# Iteración número 373
# Iteración número 374
# Iteración número 375
# Iteración número 376
# Iteración número 377
# Iteración número 378
# Iteración número 379
# Iteración número 380
# Iteración número 381
# Iteración número 382
# Iteración número 383
# Iteración número 384
# Iteración número 385
# Iteración número 386
# Iteración número 387
# Iteración número 388
# Iteración número 389
# Iteración número 390
# Iteración número 391
# Iteración número 392
# Iteración número 393
# Iteración número 394
# Iteración número 395
# Iteración número 396
# Iteración número 397
# Iteración número 398
# Iteración número 399
# Iteración número 400
# Iteración número 401
# Iteración número 402
# Iteración número 403
# Iteración número 404
# Iteración número 405
# Iteración número 406
# Iteración número 407
# Iteración número 408
# Iteración número 409
# Iteración número 410
# Iteración número 411
# Iteración número 412
# Iteración número 413
# Iteración número 414
# Iteración número 415
# Iteración número 416
# Iteración número 417
# Iteración número 418
# Iteración número 419
# Iteración número 420
# Iteración número 421
# Iteración número 422
# Iteración número 423
# Iteración número 424
# Iteración número 425
# Iteración número 426
# Iteración número 427
# Iteración número 428
# Iteración número 429
# Iteración número 430
# Iteración número 431
# Iteración número 432
# Iteración número 433
# Iteración número 434
# Iteración número 435
# Iteración número 436
# Iteración número 437
# Iteración número 438
# Iteración número 439
# Iteración número 440
# Iteración número 441
# Iteración número 442
# Iteración número 443
# Iteración número 444
# Iteración número 445
# Iteración número 446
# Iteración número 447
# Iteración número 448
# Iteración número 449
# Iteración número 450
# Iteración número 451
# Iteración número 452
# Iteración número 453
# Iteración número 454
# Iteración número 455
# Iteración número 456
# Iteración número 457
# Iteración número 458
# Iteración número 459
# Iteración número 460
# Iteración número 461
# Iteración número 462
# Iteración número 463
# Iteración número 464
# Iteración número 465
# Iteración número 466
# Iteración número 467
# Iteración número 468
# Iteración número 469
# Iteración número 470
# Iteración número 471
# Iteración número 472
# Iteración número 473
# Iteración número 474
# Iteración número 475
# Iteración número 476
# Iteración número 477
# Iteración número 478
# Iteración número 479
# Iteración número 480
# Iteración número 481
# Iteración número 482
# Iteración número 483
# Iteración número 484
# Iteración número 485
# Iteración número 486
# Iteración número 487
# Iteración número 488
# Iteración número 489
# Iteración número 490
# Iteración número 491
# Iteración número 492
# Iteración número 493
# Iteración número 494
# Iteración número 495
# Iteración número 496
# Iteración número 497
# Iteración número 498
# Iteración número 499
# Iteración número 500
# Iteración número 501
# Iteración número 502
# Iteración número 503
# Iteración número 504
# Iteración número 505
# Iteración número 506
# Iteración número 507
# Iteración número 508
# Iteración número 509
# Iteración número 510
# Iteración número 511
# Iteración número 512
# Iteración número 513
# Iteración número 514
# Iteración número 515
# Iteración número 516
# Iteración número 517
# Iteración número 518
# Iteración número 519
# Iteración número 520
# Iteración número 521
# Iteración número 522
# Iteración número 523
# Iteración número 524
# Iteración número 525
# Iteración número 526
# Iteración número 527
# Iteración número 528
# Iteración número 529
# Iteración número 530
# Iteración número 531
# Iteración número 532
# Iteración número 533
# Iteración número 534
# Iteración número 535
# Iteración número 536
# Iteración número 537
# Iteración número 538
# Iteración número 539
# Iteración número 540
# Iteración número 541
# Iteración número 542
# Iteración número 543
# Iteración número 544
# Iteración número 545
# Iteración número 546
# Iteración número 547
# Iteración número 548
# Iteración número 549
# Iteración número 550
# Iteración número 551
# Iteración número 552
# Iteración número 553
# Iteración número 554
# Iteración número 555
# Iteración número 556
# Iteración número 557
# Iteración número 558
# Iteración número 559
# Iteración número 560
# Iteración número 561
# Iteración número 562
# Iteración número 563
# Iteración número 564
# Iteración número 565
# Iteración número 566
# Iteración número 567
# Iteración número 568
# Iteración número 569
# Iteración número 570
# Iteración número 571
# Iteración número 572
# Iteración número 573
# Iteración número 574
# Iteración número 575
# Iteración número 576
# Iteración número 577
# Iteración número 578
# Iteración número 579
# Iteración número 580
# Iteración número 581
# Iteración número 582
# Iteración número 583
# Iteración número 584
# Iteración número 585
# Iteración número 586
# Iteración número 587
# Iteración número 588
# Iteración número 589
# Iteración número 590
# Iteración número 591
# Iteración número 592
# Iteración número 593
# Iteración número 594
# Iteración número 595
# Iteración número 596
# Iteración número 597
# Iteración número 598
# Iteración número 599
# Iteración número 600
# Iteración número 601
# Iteración número 602
# Iteración número 603
# Iteración número 604
# Iteración número 605
# Iteración número 606
# Iteración número 607
# Iteración número 608
# Iteración número 609
# Iteración número 610
# Iteración número 611
# Iteración número 612
# Iteración número 613
# Iteración número 614
# Iteración número 615
# Iteración número 616
# Iteración número 617
# Iteración número 618
# Iteración número 619
# Iteración número 620
# Iteración número 621
# Iteración número 622
# Iteración número 623
# Iteración número 624
# Iteración número 625
# Iteración número 626
# Iteración número 627
# Iteración número 628
# Iteración número 629
# Iteración número 630
# Iteración número 631
# Iteración número 632
# Iteración número 633
# Iteración número 634
# Iteración número 635
# Iteración número 636
# Iteración número 637
# Iteración número 638
# Iteración número 639
# Iteración número 640
# Iteración número 641
# Iteración número 642
# Iteración número 643
# Iteración número 644
# Iteración número 645
# Iteración número 646
# Iteración número 647
# Iteración número 648
# Iteración número 649
# Iteración número 650
# Iteración número 651
# Iteración número 652
# Iteración número 653
# Iteración número 654
# Iteración número 655
# Iteración número 656
# Iteración número 657
# Iteración número 658
# Iteración número 659
# Iteración número 660
# Iteración número 661
# Iteración número 662
# Iteración número 663
# Iteración número 664
# Iteración número 665
# Iteración número 666
# Iteración número 667
# Iteración número 668
# Iteración número 669
# Iteración número 670
# Iteración número 671
# Iteración número 672
# Iteración número 673
# Iteración número 674
# Iteración número 675
# Iteración número 676
# Iteración número 677
# Iteración número 678
# Iteración número 679
# Iteración número 680
# Iteración número 681
# Iteración número 682
# Iteración número 683
# Iteración número 684
# Iteración número 685
# Iteración número 686
# Iteración número 687
# Iteración número 688
# Iteración número 689
# Iteración número 690
# Iteración número 691
# Iteración número 692
# Iteración número 693
# Iteración número 694
# Iteración número 695
# Iteración número 696
# Iteración número 697
# Iteración número 698
# Iteración número 699
# Iteración número 700
# Iteración número 701
# Iteración número 702
# Iteración número 703
# Iteración número 704
# Iteración número 705
# Iteración número 706
# Iteración número 707
# Iteración número 708
# Iteración número 709
# Iteración número 710
# Iteración número 711
# Iteración número 712
# Iteración número 713
# Iteración número 714
# Iteración número 715
# Iteración número 716
# Iteración número 717
# Iteración número 718
# Iteración número 719
# Iteración número 720
# Iteración número 721
# Iteración número 722
# Iteración número 723
# Iteración número 724
# Iteración número 725
# Iteración número 726
# Iteración número 727
# Iteración número 728
# Iteración número 729
# Iteración número 730
# Iteración número 731
# Iteración número 732
# Iteración número 733
# Iteración número 734
# Iteración número 735
# Iteración número 736
# Iteración número 737
# Iteración número 738
# Iteración número 739
# Iteración número 740
# Iteración número 741
# Iteración número 742
# Iteración número 743
# Iteración número 744
# Iteración número 745
# Iteración número 746
# Iteración número 747
# Iteración número 748
# Iteración número 749
# Iteración número 750
# Iteración número 751
# Iteración número 752
# Iteración número 753
# Iteración número 754
# Iteración número 755
# Iteración número 756
# Iteración número 757
# Iteración número 758
# Iteración número 759
# Iteración número 760
# Iteración número 761
# Iteración número 762
# Iteración número 763
# Iteración número 764
# Iteración número 765
# Iteración número 766
# Iteración número 767
# Iteración número 768
# Iteración número 769
# Iteración número 770
# Iteración número 771
# Iteración número 772
# Iteración número 773
# Iteración número 774
# Iteración número 775
# Iteración número 776
# Iteración número 777
# Iteración número 778
# Iteración número 779
# Iteración número 780
# Iteración número 781
# Iteración número 782
# Iteración número 783
# Iteración número 784
# Iteración número 785
# Iteración número 786
# Iteración número 787
# Iteración número 788
# Iteración número 789
# Iteración número 790
# Iteración número 791
# Iteración número 792
# Iteración número 793
# Iteración número 794
# Iteración número 795
# Iteración número 796
# Iteración número 797
# Iteración número 798
# Iteración número 799
# Iteración número 800
# Iteración número 801
# Iteración número 802
# Iteración número 803
# Iteración número 804
# Iteración número 805
# Iteración número 806
# Iteración número 807
# Iteración número 808
# Iteración número 809
# Iteración número 810
# Iteración número 811
# Iteración número 812
# Iteración número 813
# Iteración número 814
# Iteración número 815
# Iteración número 816
# Iteración número 817
# Iteración número 818
# Iteración número 819
# Iteración número 820
# Iteración número 821
# Iteración número 822
# Iteración número 823
# Iteración número 824
# Iteración número 825
# Iteración número 826
# Iteración número 827
# Iteración número 828
# Iteración número 829
# Iteración número 830
# Iteración número 831
# Iteración número 832
# Iteración número 833
# Iteración número 834
# Iteración número 835
# Iteración número 836
# Iteración número 837
# Iteración número 838
# Iteración número 839
# Iteración número 840
# Iteración número 841
# Iteración número 842
# Iteración número 843
# Iteración número 844
# Iteración número 845
# Iteración número 846
# Iteración número 847
# Iteración número 848
# Iteración número 849
# Iteración número 850
# Iteración número 851
# Iteración número 852
# Iteración número 853
# Iteración número 854
# Iteración número 855
# Iteración número 856
# Iteración número 857
# Iteración número 858
# Iteración número 859
# Iteración número 860
# Iteración número 861
# Iteración número 862
# Iteración número 863
# Iteración número 864
# Iteración número 865
# Iteración número 866
# Iteración número 867
# Iteración número 868
# Iteración número 869
# Iteración número 870
# Iteración número 871
# Iteración número 872
# Iteración número 873
# Iteración número 874
# Iteración número 875
# Iteración número 876
# Iteración número 877
# Iteración número 878
# Iteración número 879
# Iteración número 880
# Iteración número 881
# Iteración número 882
# Iteración número 883
# Iteración número 884
# Iteración número 885
# Iteración número 886
# Iteración número 887
# Iteración número 888
# Iteración número 889
# Iteración número 890
# Iteración número 891
# Iteración número 892
# Iteración número 893
# Iteración número 894
# Iteración número 895
# Iteración número 896
# Iteración número 897
# Iteración número 898
# Iteración número 899
# Iteración número 900
# Iteración número 901
# Iteración número 902
# Iteración número 903
# Iteración número 904
# Iteración número 905
# Iteración número 906
# Iteración número 907
# Iteración número 908
# Iteración número 909
# Iteración número 910
# Iteración número 911
# Iteración número 912
# Iteración número 913
# Iteración número 914
# Iteración número 915
# Iteración número 916
# Iteración número 917
# Iteración número 918
# Iteración número 919
# Iteración número 920
# Iteración número 921
# Iteración número 922
# Iteración número 923
# Iteración número 924
# Iteración número 925
# Iteración número 926
# Iteración número 927
# Iteración número 928
# Iteración número 929
# Iteración número 930
# Iteración número 931
# Iteración número 932
# Iteración número 933
# Iteración número 934
# Iteración número 935
# Iteración número 936
# Iteración número 937
# Iteración número 938
# Iteración número 939
# Iteración número 940
# Iteración número 941
# Iteración número 942
# Iteración número 943
# Iteración número 944
# Iteración número 945
# Iteración número 946
# Iteración número 947
# Iteración número 948
# Iteración número 949
# Iteración número 950
# Iteración número 951
# Iteración número 952
# Iteración número 953
# Iteración número 954
# Iteración número 955
# Iteración número 956
# Iteración número 957
# Iteración número 958
# Iteración número 959
# Iteración número 960
# Iteración número 961
# Iteración número 962
# Iteración número 963
# Iteración número 964
# Iteración número 965
# Iteración número 966
# Iteración número 967
# Iteración número 968
# Iteración número 969
# Iteración número 970
# Iteración número 971
# Iteración número 972
# Iteración número 973
# Iteración número 974
# Iteración número 975
# Iteración número 976
# Iteración número 977
# Iteración número 978
# Iteración número 979
# Iteración número 980
# Iteración número 981
# Iteración número 982
# Iteración número 983
# Iteración número 984
# Iteración número 985
# Iteración número 986
# Iteración número 987
# Iteración número 988
# Iteración número 989
# Iteración número 990
# Iteración número 991
# Iteración número 992
# Iteración número 993
# Iteración número 994
# Iteración número 995
# Iteración número 996
# Iteración número 997
# Iteración número 998
# Iteración número 999
# Iteración número 1000
# Iteración número 1001
# Iteración número 1002
# Iteración número 1003
# Iteración número 1004
# Iteración número 1005
# Iteración número 1006
# Iteración número 1007
# Iteración número 1008
# Iteración número 1009
# Iteración número 1010
# Iteración número 1011
# Iteración número 1012
# Iteración número 1013
# Iteración número 1014
# Iteración número 1015
# Iteración número 1016
# Iteración número 1017
# Iteración número 1018
# Iteración número 1019
# Iteración número 1020
# Iteración número 1021
# Iteración número 1022
# Iteración número 1023
# Iteración número 1024
# Iteración número 1025
# Iteración número 1026
# Iteración número 1027
# Iteración número 1028
# Iteración número 1029
# Iteración número 1030
# Iteración número 1031
# Iteración número 1032
# Iteración número 1033
# Iteración número 1034
# Iteración número 1035
# Iteración número 1036
# Iteración número 1037
# Iteración número 1038
# Iteración número 1039
# Iteración número 1040
# Iteración número 1041
# Iteración número 1042
# Iteración número 1043
# Iteración número 1044
# Iteración número 1045
# Iteración número 1046
# Iteración número 1047
# Iteración número 1048
# Iteración número 1049
# Iteración número 1050
# Iteración número 1051
# Iteración número 1052
# Iteración número 1053
# Iteración número 1054
# Iteración número 1055
# Iteración número 1056
# Iteración número 1057
# Iteración número 1058
# Iteración número 1059
# Iteración número 1060
# Iteración número 1061
# Iteración número 1062
# Iteración número 1063
# Iteración número 1064
# Iteración número 1065
# Iteración número 1066
# Iteración número 1067
# Iteración número 1068
# Iteración número 1069
# Iteración número 1070
# Iteración número 1071
# Iteración número 1072
# Iteración número 1073
# Iteración número 1074
# Iteración número 1075
# Iteración número 1076
# Iteración número 1077
# Iteración número 1078
# Iteración número 1079
# Iteración número 1080
# Iteración número 1081
# Iteración número 1082
# Iteración número 1083
# Iteración número 1084
# Iteración número 1085
# Iteración número 1086
# Iteración número 1087
# Iteración número 1088
# Iteración número 1089
# Iteración número 1090
# Iteración número 1091
# Iteración número 1092
# Iteración número 1093
# Iteración número 1094
# Iteración número 1095
# Iteración número 1096
# Iteración número 1097
# Iteración número 1098
# Iteración número 1099
# Iteración número 1100
# Iteración número 1101
# Iteración número 1102
# Iteración número 1103
# Iteración número 1104
# Iteración número 1105
# Iteración número 1106
# Iteración número 1107
# Iteración número 1108
# Iteración número 1109
# Iteración número 1110
# Iteración número 1111
# Iteración número 1112
# Iteración número 1113
# Iteración número 1114
# Iteración número 1115
# Iteración número 1116
# Iteración número 1117
# Iteración número 1118
# Iteración número 1119
# Iteración número 1120
# Iteración número 1121
# Iteración número 1122
# Iteración número 1123
# Iteración número 1124
# Iteración número 1125
# Iteración número 1126
# Iteración número 1127
# Iteración número 1128
# Iteración número 1129
# Iteración número 1130
# Iteración número 1131
# Iteración número 1132
# Iteración número 1133
# Iteración número 1134
# Iteración número 1135
# Iteración número 1136
# Iteración número 1137
# Iteración número 1138
# Iteración número 1139
# Iteración número 1140
# Iteración número 1141
# Iteración número 1142
# Iteración número 1143
# Iteración número 1144
# Iteración número 1145
# Iteración número 1146
# Iteración número 1147
# Iteración número 1148
# Iteración número 1149
# Iteración número 1150
# Iteración número 1151
# Iteración número 1152
# Iteración número 1153
# Iteración número 1154
# Iteración número 1155
# Iteración número 1156
# Iteración número 1157
# Iteración número 1158
# Iteración número 1159
# Iteración número 1160
# Iteración número 1161
# Iteración número 1162
# Iteración número 1163
# Iteración número 1164
# Iteración número 1165
# Iteración número 1166
# Iteración número 1167
# Iteración número 1168
# Iteración número 1169
# Iteración número 1170
# Iteración número 1171
# Iteración número 1172
# Iteración número 1173
# Iteración número 1174
# Iteración número 1175
# Iteración número 1176
# Iteración número 1177
# Iteración número 1178
# Iteración número 1179
# Iteración número 1180
# Iteración número 1181
# Iteración número 1182
# Iteración número 1183
# Iteración número 1184
# Iteración número 1185
# Iteración número 1186
# Iteración número 1187
# Iteración número 1188
# Iteración número 1189
# Iteración número 1190
# Iteración número 1191
# Iteración número 1192
# Iteración número 1193
# Iteración número 1194
# Iteración número 1195
# Iteración número 1196
# Iteración número 1197
# Iteración número 1198
# Iteración número 1199
# Iteración número 1200
# Iteración número 1201
# Iteración número 1202
# Iteración número 1203
# Iteración número 1204
# Iteración número 1205
# Iteración número 1206
# Iteración número 1207
# Iteración número 1208
# Iteración número 1209
# Iteración número 1210
# Iteración número 1211
# Iteración número 1212
# Iteración número 1213
# Iteración número 1214
# Iteración número 1215
# Iteración número 1216
# Iteración número 1217
# Iteración número 1218
# Iteración número 1219
# Iteración número 1220
# Iteración número 1221
# Iteración número 1222
# Iteración número 1223
# Iteración número 1224
# Iteración número 1225
# Iteración número 1226
# Iteración número 1227
# Iteración número 1228
# Iteración número 1229
# Iteración número 1230
# Iteración número 1231
# Iteración número 1232
# Iteración número 1233
# Iteración número 1234
# Iteración número 1235
# Iteración número 1236
# Iteración número 1237
# Iteración número 1238
# Iteración número 1239
# Iteración número 1240
# Iteración número 1241
# Iteración número 1242
# Iteración número 1243
# Iteración número 1244
# Iteración número 1245
# Iteración número 1246
# Iteración número 1247
# Iteración número 1248
# Iteración número 1249
# Iteración número 1250
# Iteración número 1251
# Iteración número 1252
# Iteración número 1253
# Iteración número 1254
# Iteración número 1255
# Iteración número 1256
# Iteración número 1257
# Iteración número 1258
# Iteración número 1259
# Iteración número 1260
# Iteración número 1261
# Iteración número 1262
# Iteración número 1263
# Iteración número 1264
# Iteración número 1265
# Iteración número 1266
# Iteración número 1267
# Iteración número 1268
# Iteración número 1269
# Iteración número 1270
# Iteración número 1271
# Iteración número 1272
# Iteración número 1273
# Iteración número 1274
# Iteración número 1275
# Iteración número 1276
# Iteración número 1277
# Iteración número 1278
# Iteración número 1279
# Iteración número 1280
# Iteración número 1281
# Iteración número 1282
# Iteración número 1283
# Iteración número 1284
# Iteración número 1285
# Iteración número 1286
# Iteración número 1287
# Iteración número 1288
# Iteración número 1289
# Iteración número 1290
# Iteración número 1291
# Iteración número 1292
# Iteración número 1293
# Iteración número 1294
# Iteración número 1295
# Iteración número 1296
# Iteración número 1297
# Iteración número 1298
# Iteración número 1299
# Iteración número 1300
# Iteración número 1301
# Iteración número 1302
# Iteración número 1303
# Iteración número 1304
# Iteración número 1305
# Iteración número 1306
# Iteración número 1307
# Iteración número 1308
# Iteración número 1309
# Iteración número 1310
# Iteración número 1311
# Iteración número 1312
# Iteración número 1313
# Iteración número 1314
# Iteración número 1315
# Iteración número 1316
# Iteración número 1317
# Iteración número 1318
# Iteración número 1319
# Iteración número 1320
# Iteración número 1321
# Iteración número 1322
# Iteración número 1323
# Iteración número 1324
# Iteración número 1325
# Iteración número 1326
# Iteración número 1327
# Iteración número 1328
# Iteración número 1329
# Iteración número 1330
# Iteración número 1331
# Iteración número 1332
# Iteración número 1333
# Iteración número 1334
# Iteración número 1335
# Iteración número 1336
# Iteración número 1337
# Iteración número 1338
# Iteración número 1339
# Iteración número 1340
# Iteración número 1341
# Iteración número 1342
# Iteración número 1343
# Iteración número 1344
# Iteración número 1345
# Iteración número 1346
# Iteración número 1347
# Iteración número 1348
# Iteración número 1349
# Iteración número 1350
# Iteración número 1351
# Iteración número 1352
# Iteración número 1353
# Iteración número 1354
# Iteración número 1355
# Iteración número 1356
# Iteración número 1357
# Iteración número 1358
# Iteración número 1359
# Iteración número 1360
# Iteración número 1361
# Iteración número 1362
# Iteración número 1363
# Iteración número 1364
# Iteración número 1365
# Iteración número 1366
# Iteración número 1367
# Iteración número 1368
# Iteración número 1369
# Iteración número 1370
# Iteración número 1371
# Iteración número 1372
# Iteración número 1373
# Iteración número 1374
# Iteración número 1375
# Iteración número 1376
# Iteración número 1377
# Iteración número 1378
# Iteración número 1379
# Iteración número 1380
# Iteración número 1381
# Iteración número 1382
# Iteración número 1383
# Iteración número 1384
# Iteración número 1385
# Iteración número 1386
# Iteración número 1387
# Iteración número 1388
# Iteración número 1389
# Iteración número 1390
# Iteración número 1391
# Iteración número 1392
# Iteración número 1393
# Iteración número 1394
# Iteración número 1395
# Iteración número 1396
# Iteración número 1397
# Iteración número 1398
# Iteración número 1399
# Iteración número 1400
# Iteración número 1401
# Iteración número 1402
# Iteración número 1403
# Iteración número 1404
# Iteración número 1405
# Iteración número 1406
# Iteración número 1407
# Iteración número 1408
# Iteración número 1409
# Iteración número 1410
# Iteración número 1411
# Iteración número 1412
# Iteración número 1413
# Iteración número 1414
# Iteración número 1415
# Iteración número 1416
# Iteración número 1417
# Iteración número 1418
# Iteración número 1419
# Iteración número 1420
# Iteración número 1421
# Iteración número 1422
# Iteración número 1423
# Iteración número 1424
# Iteración número 1425
# Iteración número 1426
# Iteración número 1427
# Iteración número 1428
# Iteración número 1429
# Iteración número 1430
# Iteración número 1431
# Iteración número 1432
# Iteración número 1433
# Iteración número 1434
# Iteración número 1435
# Iteración número 1436
# Iteración número 1437
# Iteración número 1438
# Iteración número 1439
# Iteración número 1440
# Iteración número 1441
# Iteración número 1442
# Iteración número 1443
# Iteración número 1444
# Iteración número 1445
# Iteración número 1446
# Iteración número 1447
# Iteración número 1448
# Iteración número 1449
# Iteración número 1450
# Iteración número 1451
# Iteración número 1452
# Iteración número 1453
# Iteración número 1454
# Iteración número 1455
# Iteración número 1456
# Iteración número 1457
# Iteración número 1458
# Iteración número 1459
# Iteración número 1460
# Iteración número 1461
# Iteración número 1462
# Iteración número 1463
# Iteración número 1464
# Iteración número 1465
# Iteración número 1466
# Iteración número 1467
# Iteración número 1468
# Iteración número 1469
# Iteración número 1470
# Iteración número 1471
# Iteración número 1472
# Iteración número 1473
# Iteración número 1474
# Iteración número 1475
# Iteración número 1476
# Iteración número 1477
# Iteración número 1478
# Iteración número 1479
# Iteración número 1480
# Iteración número 1481
# Iteración número 1482
# Iteración número 1483
# Iteración número 1484
# Iteración número 1485
# Iteración número 1486
# Iteración número 1487
# Iteración número 1488
# Iteración número 1489
# Iteración número 1490
# Iteración número 1491
# Iteración número 1492
# Iteración número 1493
# Iteración número 1494
# Iteración número 1495
# Iteración número 1496
# Iteración número 1497
# Iteración número 1498
# Iteración número 1499
# Iteración número 1500
# Iteración número 1501
# Iteración número 1502
# Iteración número 1503
# Iteración número 1504
# Iteración número 1505
# Iteración número 1506
# Iteración número 1507
# Iteración número 1508
# Iteración número 1509
# Iteración número 1510
# Iteración número 1511
# Iteración número 1512
# Iteración número 1513
# Iteración número 1514
# Iteración número 1515
# Iteración número 1516
# Iteración número 1517
# Iteración número 1518
# Iteración número 1519
# Iteración número 1520
# Iteración número 1521
# Iteración número 1522
# Iteración número 1523
# Iteración número 1524
# Iteración número 1525
# Iteración número 1526
# Iteración número 1527
# Iteración número 1528
# Iteración número 1529
# Iteración número 1530
# Iteración número 1531
# Iteración número 1532
# Iteración número 1533
# Iteración número 1534
# Iteración número 1535
# Iteración número 1536
# Iteración número 1537
# Iteración número 1538
# Iteración número 1539
# Iteración número 1540
# Iteración número 1541
# Iteración número 1542
# Iteración número 1543
# Iteración número 1544
# Iteración número 1545
# Iteración número 1546
# Iteración número 1547
# Iteración número 1548
# Iteración número 1549
# Iteración número 1550
# Iteración número 1551
# Iteración número 1552
# Iteración número 1553
# Iteración número 1554
# Iteración número 1555
# Iteración número 1556
# Iteración número 1557
# Iteración número 1558
# Iteración número 1559
# Iteración número 1560
# Iteración número 1561
# Iteración número 1562
# Iteración número 1563
# Iteración número 1564
# Iteración número 1565
# Iteración número 1566
# Iteración número 1567
# Iteración número 1568
# Iteración número 1569
# Iteración número 1570
# Iteración número 1571
# Iteración número 1572
# Iteración número 1573
# Iteración número 1574
# Iteración número 1575
# Iteración número 1576
# Iteración número 1577
# Iteración número 1578
# Iteración número 1579
# Iteración número 1580
# Iteración número 1581
# Iteración número 1582
# Iteración número 1583
# Iteración número 1584
# Iteración número 1585
# Iteración número 1586
# Iteración número 1587
# Iteración número 1588
# Iteración número 1589
# Iteración número 1590
# Iteración número 1591
# Iteración número 1592
# Iteración número 1593
# Iteración número 1594
# Iteración número 1595
# Iteración número 1596
# Iteración número 1597
# Iteración número 1598
# Iteración número 1599
# Iteración número 1600
# Iteración número 1601
# Iteración número 1602
# Iteración número 1603
# Iteración número 1604
# Iteración número 1605
# Iteración número 1606
# Iteración número 1607
# Iteración número 1608
# Iteración número 1609
# Iteración número 1610
# Iteración número 1611
# Iteración número 1612
# Iteración número 1613
# Iteración número 1614
# Iteración número 1615
# Iteración número 1616
# Iteración número 1617
# Iteración número 1618
# Iteración número 1619
# Iteración número 1620
# Iteración número 1621
# Iteración número 1622
# Iteración número 1623
# Iteración número 1624
# Iteración número 1625
# Iteración número 1626
# Iteración número 1627
# Iteración número 1628
# Iteración número 1629
# Iteración número 1630
# Iteración número 1631
# Iteración número 1632
# Iteración número 1633
# Iteración número 1634
# Iteración número 1635
# Iteración número 1636
# Iteración número 1637
# Iteración número 1638
# Iteración número 1639
# Iteración número 1640
# Iteración número 1641
# Iteración número 1642
# Iteración número 1643
# Iteración número 1644
# Iteración número 1645
# Iteración número 1646
# Iteración número 1647
# Iteración número 1648
# Iteración número 1649
# Iteración número 1650
# Iteración número 1651
# Iteración número 1652
# Iteración número 1653
# Iteración número 1654
# Iteración número 1655
# Iteración número 1656
# Iteración número 1657
# Iteración número 1658
# Iteración número 1659
# Iteración número 1660
# Iteración número 1661
# Iteración número 1662
# Iteración número 1663
# Iteración número 1664
# Iteración número 1665
# Iteración número 1666
# Iteración número 1667
# Iteración número 1668
# Iteración número 1669
# Iteración número 1670
# Iteración número 1671
# Iteración número 1672
# Iteración número 1673
# Iteración número 1674
# Iteración número 1675
# Iteración número 1676
# Iteración número 1677
# Iteración número 1678
# Iteración número 1679
# Iteración número 1680
# Iteración número 1681
# Iteración número 1682
# Iteración número 1683
# Iteración número 1684
# Iteración número 1685
# Iteración número 1686
# Iteración número 1687
# Iteración número 1688
# Iteración número 1689
# Iteración número 1690
# Iteración número 1691
# Iteración número 1692
# Iteración número 1693
# Iteración número 1694
# Iteración número 1695
# Iteración número 1696
# Iteración número 1697
# Iteración número 1698
# Iteración número 1699
# Iteración número 1700
# Iteración número 1701
# Iteración número 1702
# Iteración número 1703
# Iteración número 1704
# Iteración número 1705
# Iteración número 1706
# Iteración número 1707
# Iteración número 1708
# Iteración número 1709
# Iteración número 1710
# Iteración número 1711
# Iteración número 1712
# Iteración número 1713
# Iteración número 1714
# Iteración número 1715
# Iteración número 1716
# Iteración número 1717
# Iteración número 1718
# Iteración número 1719
# Iteración número 1720
# Iteración número 1721
# Iteración número 1722
# Iteración número 1723
# Iteración número 1724
# Iteración número 1725
# Iteración número 1726
# Iteración número 1727
# Iteración número 1728
# Iteración número 1729
# Iteración número 1730
# Iteración número 1731
# Iteración número 1732
# Iteración número 1733
# Iteración número 1734
# Iteración número 1735
# Iteración número 1736
# Iteración número 1737
# Iteración número 1738
# Iteración número 1739
# Iteración número 1740
# Iteración número 1741
# Iteración número 1742
# Iteración número 1743
# Iteración número 1744
# Iteración número 1745
# Iteración número 1746
# Iteración número 1747
# Iteración número 1748
# Iteración número 1749
# Iteración número 1750
# Iteración número 1751
# Iteración número 1752
# Iteración número 1753
# Iteración número 1754
# Iteración número 1755
# Iteración número 1756
# Iteración número 1757
# Iteración número 1758
# Iteración número 1759
# Iteración número 1760
# Iteración número 1761
# Iteración número 1762
# Iteración número 1763
# Iteración número 1764
# Iteración número 1765
# Iteración número 1766
# Iteración número 1767
# Iteración número 1768
# Iteración número 1769
# Iteración número 1770
# Iteración número 1771
# Iteración número 1772
# Iteración número 1773
# Iteración número 1774
# Iteración número 1775
# Iteración número 1776
# Iteración número 1777
# Iteración número 1778
# Iteración número 1779
# Iteración número 1780
# Iteración número 1781
# Iteración número 1782
# Iteración número 1783
# Iteración número 1784
# Iteración número 1785
# Iteración número 1786
# Iteración número 1787
# Iteración número 1788
# Iteración número 1789
# Iteración número 1790
# Iteración número 1791
# Iteración número 1792
# Iteración número 1793
# Iteración número 1794
# Iteración número 1795
# Iteración número 1796
# Iteración número 1797
# Iteración número 1798
# Iteración número 1799
# Iteración número 1800
# Iteración número 1801
# Iteración número 1802
# Iteración número 1803
# Iteración número 1804
# Iteración número 1805
# Iteración número 1806
# Iteración número 1807
# Iteración número 1808
# Iteración número 1809
# Iteración número 1810
# Iteración número 1811
# Iteración número 1812
# Iteración número 1813
# Iteración número 1814
# Iteración número 1815
# Iteración número 1816
# Iteración número 1817
# Iteración número 1818
# Iteración número 1819
# Iteración número 1820
# Iteración número 1821
# Iteración número 1822
# Iteración número 1823
# Iteración número 1824
# Iteración número 1825
# Iteración número 1826
# Iteración número 1827
# Iteración número 1828
# Iteración número 1829
# Iteración número 1830
# Iteración número 1831
# Iteración número 1832
# Iteración número 1833
# Iteración número 1834
# Iteración número 1835
# Iteración número 1836
# Iteración número 1837
# Iteración número 1838
# Iteración número 1839
# Iteración número 1840
# Iteración número 1841
# Iteración número 1842
# Iteración número 1843
# Iteración número 1844
# Iteración número 1845
# Iteración número 1846
# Iteración número 1847
# Iteración número 1848
# Iteración número 1849
# Iteración número 1850
# Iteración número 1851
# Iteración número 1852
# Iteración número 1853
# Iteración número 1854
# Iteración número 1855
# Iteración número 1856
# Iteración número 1857
# Iteración número 1858
# Iteración número 1859
# Iteración número 1860
# Iteración número 1861
# Iteración número 1862
# Iteración número 1863
# Iteración número 1864
# Iteración número 1865
# Iteración número 1866
# Iteración número 1867
# Iteración número 1868
# Iteración número 1869
# Iteración número 1870
# Iteración número 1871
# Iteración número 1872
# Iteración número 1873
# Iteración número 1874
# Iteración número 1875
# Iteración número 1876
# Iteración número 1877
# Iteración número 1878
# Iteración número 1879
# Iteración número 1880
# Iteración número 1881
# Iteración número 1882
# Iteración número 1883
# Iteración número 1884
# Iteración número 1885
# Iteración número 1886
# Iteración número 1887
# Iteración número 1888
# Iteración número 1889
# Iteración número 1890
# Iteración número 1891
# Iteración número 1892
# Iteración número 1893
# Iteración número 1894
# Iteración número 1895
# Iteración número 1896
# Iteración número 1897
# Iteración número 1898
# Iteración número 1899
# Iteración número 1900
# Iteración número 1901
# Iteración número 1902
# Iteración número 1903
# Iteración número 1904
# Iteración número 1905
# Iteración número 1906
# Iteración número 1907
# Iteración número 1908
# Iteración número 1909
# Iteración número 1910
# Iteración número 1911
# Iteración número 1912
# Iteración número 1913
# Iteración número 1914
# Iteración número 1915
# Iteración número 1916
# Iteración número 1917
# Iteración número 1918
# Iteración número 1919
# Iteración número 1920
# Iteración número 1921
# Iteración número 1922
# Iteración número 1923
# Iteración número 1924
# Iteración número 1925
# Iteración número 1926
# Iteración número 1927
# Iteración número 1928
# Iteración número 1929
# Iteración número 1930
# Iteración número 1931
# Iteración número 1932
# Iteración número 1933
# Iteración número 1934
# Iteración número 1935
# Iteración número 1936
# Iteración número 1937
# Iteración número 1938
# Iteración número 1939
# Iteración número 1940
# Iteración número 1941
# Iteración número 1942
# Iteración número 1943
# Iteración número 1944
# Iteración número 1945
# Iteración número 1946
# status is 403
# status is 403
# status is 403
#
# start the 4 minute wait
# 1 minutes have passed
# 2 minutes have passed
# 3 minutes have passed
# 4 minutes have passed
# Iteración número 1947
# Iteración número 1948
# Iteración número 1949
# Iteración número 1950
# Iteración número 1951
# Iteración número 1952
# Iteración número 1953
# Iteración número 1954
# Iteración número 1955
# Iteración número 1956
# Iteración número 1957
# Iteración número 1958
# Iteración número 1959
# Iteración número 1960
# Iteración número 1961
# Iteración número 1962
# Iteración número 1963
# Iteración número 1964
# Iteración número 1965
# Iteración número 1966
# Iteración número 1967
# Iteración número 1968
# Iteración número 1969
# Iteración número 1970
# Iteración número 1971
# Iteración número 1972
# Iteración número 1973
# Iteración número 1974
# Iteración número 1975
# Iteración número 1976
# Iteración número 1977
# Iteración número 1978
# Iteración número 1979
# Iteración número 1980
# Iteración número 1981
# Iteración número 1982
# Iteración número 1983
# Iteración número 1984
# Iteración número 1985
# Iteración número 1986
# Iteración número 1987
# Iteración número 1988
# Iteración número 1989
# Iteración número 1990
# Iteración número 1991
# Iteración número 1992
# Iteración número 1993
# Iteración número 1994
# Iteración número 1995
# Iteración número 1996
# Iteración número 1997
# Iteración número 1998
# Iteración número 1999
# Iteración número 2000
# Iteración número 2001
# Iteración número 2002
# Iteración número 2003
# Iteración número 2004
# Iteración número 2005
# Iteración número 2006
# Iteración número 2007
# Iteración número 2008
# Iteración número 2009
# Iteración número 2010
# Iteración número 2011
# Iteración número 2012
# Iteración número 2013
# Iteración número 2014
# Iteración número 2015
# Iteración número 2016
# Iteración número 2017
# Iteración número 2018
# Iteración número 2019
# Iteración número 2020
# Iteración número 2021
# Iteración número 2022
# Iteración número 2023
# Iteración número 2024
# Iteración número 2025
# Iteración número 2026
# Iteración número 2027
# Iteración número 2028
# Iteración número 2029
# Iteración número 2030
# Iteración número 2031
# Iteración número 2032
# Iteración número 2033
# Iteración número 2034
# Iteración número 2035
# Iteración número 2036
# Iteración número 2037
# Iteración número 2038
# Iteración número 2039
# Iteración número 2040
# Iteración número 2041
# Iteración número 2042
# Iteración número 2043
# Iteración número 2044
# Iteración número 2045
# Iteración número 2046
# Iteración número 2047
# Iteración número 2048
# Iteración número 2049
# Iteración número 2050
# Iteración número 2051
# Iteración número 2052
# Iteración número 2053
# Iteración número 2054
# Iteración número 2055
# Iteración número 2056
# Iteración número 2057
# Iteración número 2058
# Iteración número 2059
# Iteración número 2060
# Iteración número 2061
# Iteración número 2062
# Iteración número 2063
# Iteración número 2064
# Iteración número 2065
# Iteración número 2066
# Iteración número 2067
# Iteración número 2068
# Iteración número 2069
# Iteración número 2070
# Iteración número 2071
# Iteración número 2072
# Iteración número 2073
# Iteración número 2074
# Iteración número 2075
# Iteración número 2076
# status is 403
# status is 403
# status is 403
#
# start the 4 minute wait
# 1 minutes have passed
# 2 minutes have passed
# 3 minutes have passed
# 4 minutes have passed
# Iteración número 2077
# Iteración número 2078
# Iteración número 2079
# Iteración número 2080
# Iteración número 2081
# Iteración número 2082
# Iteración número 2083
# Iteración número 2084
# Iteración número 2085
# Iteración número 2086
# Iteración número 2087
# Iteración número 2088
# Iteración número 2089
# Iteración número 2090
# Iteración número 2091
# Iteración número 2092
# Iteración número 2093
# Iteración número 2094
# Iteración número 2095
# Iteración número 2096
# Iteración número 2097
# Iteración número 2098
# Iteración número 2099
# Iteración número 2100
# Iteración número 2101
# Iteración número 2102
# Iteración número 2103
# Iteración número 2104
# Iteración número 2105
# Iteración número 2106
# Iteración número 2107
# Iteración número 2108
# Iteración número 2109
# Iteración número 2110
# Iteración número 2111
# Iteración número 2112
# Iteración número 2113
# Iteración número 2114
# Iteración número 2115
# Iteración número 2116
# Iteración número 2117
# Iteración número 2118
# Iteración número 2119
# Iteración número 2120
# Iteración número 2121
# Iteración número 2122
# Iteración número 2123
# Iteración número 2124
# Iteración número 2125
# Iteración número 2126
# Iteración número 2127
# Iteración número 2128
# Iteración número 2129
# Iteración número 2130
# Iteración número 2131
# Iteración número 2132
# Iteración número 2133
# Iteración número 2134
# Iteración número 2135
# Iteración número 2136
# Iteración número 2137
# Iteración número 2138
# Iteración número 2139
# Iteración número 2140
# Iteración número 2141
# Iteración número 2142
# Iteración número 2143
# Iteración número 2144
# Iteración número 2145
# Iteración número 2146
# Iteración número 2147
# Iteración número 2148
# Iteración número 2149
# Iteración número 2150
# Iteración número 2151
# Iteración número 2152
# Iteración número 2153
# Iteración número 2154
# Iteración número 2155
# Iteración número 2156
# Iteración número 2157
# Iteración número 2158
# Iteración número 2159
# Iteración número 2160
# Iteración número 2161
# Iteración número 2162
# Iteración número 2163
# Iteración número 2164
# Iteración número 2165
# Iteración número 2166
# Iteración número 2167
# Iteración número 2168
# Iteración número 2169
# Iteración número 2170
# Iteración número 2171
# Iteración número 2172
# Iteración número 2173
# Iteración número 2174
# Iteración número 2175
# Iteración número 2176
# Iteración número 2177
# Iteración número 2178
# Iteración número 2179
# Iteración número 2180
# Iteración número 2181
# Iteración número 2182
# Iteración número 2183
# Iteración número 2184
# Iteración número 2185
# Iteración número 2186
# Iteración número 2187
# Iteración número 2188
# Iteración número 2189
# Iteración número 2190
# Iteración número 2191
# Iteración número 2192
# Iteración número 2193
# Iteración número 2194
# Iteración número 2195
# Iteración número 2196
# Iteración número 2197
# status is 403
# status is 403
# status is 403
#
# start the 4 minute wait
# 1 minutes have passed
# 2 minutes have passed
# 3 minutes have passed
# 4 minutes have passed
# Iteración número 2198
# Iteración número 2199
# Iteración número 2200
# Iteración número 2201
# Iteración número 2202
# Iteración número 2203
# Iteración número 2204
# Iteración número 2205
# Iteración número 2206
# Iteración número 2207
# Iteración número 2208
# Iteración número 2209
# Iteración número 2210
# Iteración número 2211
# Iteración número 2212
# Iteración número 2213
# Iteración número 2214
# Iteración número 2215
# Iteración número 2216
# Iteración número 2217
# Iteración número 2218
# Iteración número 2219
# Iteración número 2220
# Iteración número 2221
# Iteración número 2222
# Iteración número 2223
# Iteración número 2224
# Iteración número 2225
# Iteración número 2226
# Iteración número 2227
# Iteración número 2228
# Iteración número 2229
# Iteración número 2230
# Iteración número 2231
# Iteración número 2232
# Iteración número 2233
# Iteración número 2234
# Iteración número 2235
# Iteración número 2236
# Iteración número 2237
# Iteración número 2238
# Iteración número 2239
# Iteración número 2240
# Iteración número 2241
# Iteración número 2242
# Iteración número 2243
# Iteración número 2244
# Iteración número 2245
# Iteración número 2246
# Iteración número 2247
# Iteración número 2248
# Iteración número 2249
# Iteración número 2250
# Iteración número 2251
# Iteración número 2252
# Iteración número 2253
# Iteración número 2254
# Iteración número 2255
# Iteración número 2256
# Iteración número 2257
# Iteración número 2258
# Iteración número 2259
# Iteración número 2260
# Iteración número 2261
# Iteración número 2262
# Iteración número 2263
# Iteración número 2264
# Iteración número 2265
# Iteración número 2266
# Iteración número 2267
# Iteración número 2268
# Iteración número 2269
# Iteración número 2270
# Iteración número 2271
# Iteración número 2272
# Iteración número 2273
# Iteración número 2274
# Iteración número 2275
# Iteración número 2276
# Iteración número 2277
# Iteración número 2278
# Iteración número 2279
# Iteración número 2280
# Iteración número 2281
# Iteración número 2282
# Iteración número 2283
# Iteración número 2284
# Iteración número 2285
# Iteración número 2286
# Iteración número 2287
# Iteración número 2288
# Iteración número 2289
# Iteración número 2290
# Iteración número 2291
# Iteración número 2292
# Iteración número 2293
# Iteración número 2294
# Iteración número 2295
# Iteración número 2296
# Iteración número 2297
# Iteración número 2298
# Iteración número 2299
# Iteración número 2300
# Iteración número 2301
# Iteración número 2302
# Iteración número 2303
# Iteración número 2304
# Iteración número 2305
# Iteración número 2306
# Iteración número 2307
# Iteración número 2308
# Iteración número 2309
# Iteración número 2310
# Iteración número 2311
# Iteración número 2312
# status is 403
# status is 403
# status is 403
#
# start the 4 minute wait
# 1 minutes have passed
# 2 minutes have passed
# 3 minutes have passed
# 4 minutes have passed
# Iteración número 2313
# Iteración número 2314
# Iteración número 2315
# Iteración número 2316
# Iteración número 2317
# Iteración número 2318
# Iteración número 2319
# Iteración número 2320
# Iteración número 2321
# Iteración número 2322
# Iteración número 2323
# Iteración número 2324
# Iteración número 2325
# Iteración número 2326
# Iteración número 2327
# Iteración número 2328
# Iteración número 2329
# Iteración número 2330
# Iteración número 2331
# Iteración número 2332
# Iteración número 2333
# Iteración número 2334
# Iteración número 2335
# Iteración número 2336
# Iteración número 2337
# Iteración número 2338
# Iteración número 2339
# Iteración número 2340
# Iteración número 2341
# Iteración número 2342
# Iteración número 2343
# Iteración número 2344
# Iteración número 2345
# Iteración número 2346
# Iteración número 2347
# Iteración número 2348
# Iteración número 2349
# Iteración número 2350
# Iteración número 2351
# Iteración número 2352
# Iteración número 2353
# Iteración número 2354
# Iteración número 2355
# Iteración número 2356
# Iteración número 2357
# Iteración número 2358
# Iteración número 2359
# Iteración número 2360
# Iteración número 2361
# Iteración número 2362
# Iteración número 2363
# Iteración número 2364
# Iteración número 2365
# Iteración número 2366
# Iteración número 2367
# Iteración número 2368
# Iteración número 2369
# Iteración número 2370
# Iteración número 2371
# Iteración número 2372
# Iteración número 2373
# Iteración número 2374
# Iteración número 2375
# Iteración número 2376
# Iteración número 2377
# Iteración número 2378
# Iteración número 2379
# Iteración número 2380
# Iteración número 2381
# Iteración número 2382
# Iteración número 2383
# Iteración número 2384
# Iteración número 2385
# Iteración número 2386
# Iteración número 2387
# Iteración número 2388
# Iteración número 2389
# Iteración número 2390
# Iteración número 2391
# Iteración número 2392
# Iteración número 2393
# Iteración número 2394
# Iteración número 2395
# Iteración número 2396
# Iteración número 2397
# Iteración número 2398
# Iteración número 2399
# Iteración número 2400
# Iteración número 2401
# Iteración número 2402
# Iteración número 2403
# Iteración número 2404
# Iteración número 2405
# Iteración número 2406
# Iteración número 2407
# Iteración número 2408
# Iteración número 2409
# Iteración número 2410
# Iteración número 2411
# Iteración número 2412
# Iteración número 2413
# Iteración número 2414
# Iteración número 2415
# Iteración número 2416
# Iteración número 2417
# Iteración número 2418
# Iteración número 2419
# Iteración número 2420
# Iteración número 2421
# Iteración número 2422
# Iteración número 2423
# Iteración número 2424
# Iteración número 2425
# Iteración número 2426
# Iteración número 2427
# Iteración número 2428
# Iteración número 2429
# Iteración número 2430
# Iteración número 2431
# Iteración número 2432
# status is 403
# status is 403
# status is 403
#
# start the 4 minute wait
# 1 minutes have passed
# 2 minutes have passed
# 3 minutes have passed
# 4 minutes have passed
# Iteración número 2433
# Iteración número 2434
# Iteración número 2435
# Iteración número 2436
# Iteración número 2437
# Iteración número 2438
# Iteración número 2439
# Iteración número 2440
# Iteración número 2441
# Iteración número 2442
# Iteración número 2443
# Iteración número 2444
# Iteración número 2445
# Iteración número 2446
# Iteración número 2447
# Iteración número 2448
# Iteración número 2449
# Iteración número 2450
# Iteración número 2451
# Iteración número 2452
# Iteración número 2453
# Iteración número 2454
# Iteración número 2455
# Iteración número 2456
# Iteración número 2457
# Iteración número 2458
# Iteración número 2459
# Iteración número 2460
# Iteración número 2461
# Iteración número 2462
# Iteración número 2463
# Iteración número 2464
# Iteración número 2465
# Iteración número 2466
# Iteración número 2467
# Iteración número 2468
# Iteración número 2469
# Iteración número 2470
# Iteración número 2471
# Iteración número 2472
# Iteración número 2473
# Iteración número 2474
# Iteración número 2475
# Iteración número 2476
# Iteración número 2477
# Iteración número 2478
# Iteración número 2479
# Iteración número 2480
# Iteración número 2481
# Iteración número 2482
# Iteración número 2483
# Iteración número 2484
# Iteración número 2485
# Iteración número 2486
# Iteración número 2487
# Iteración número 2488
# Iteración número 2489
# Iteración número 2490
# Iteración número 2491
# Iteración número 2492
# Iteración número 2493
# Iteración número 2494
# Iteración número 2495
# Iteración número 2496
# Iteración número 2497
# Iteración número 2498
# Iteración número 2499
# Iteración número 2500
# Iteración número 2501
# Iteración número 2502
# Iteración número 2503
# Iteración número 2504
# Iteración número 2505
# Iteración número 2506
# Iteración número 2507
# Iteración número 2508
# Iteración número 2509
# Iteración número 2510
# Iteración número 2511
# Iteración número 2512
# Iteración número 2513
# Iteración número 2514
# Iteración número 2515
# Iteración número 2516
# Iteración número 2517
# Iteración número 2518
# Iteración número 2519
# Iteración número 2520
# Iteración número 2521
# Iteración número 2522
# Iteración número 2523
# Iteración número 2524
# Iteración número 2525
# Iteración número 2526
# Iteración número 2527
# Iteración número 2528
# Iteración número 2529
# Iteración número 2530
# Iteración número 2531
# Iteración número 2532
# Iteración número 2533
# Iteración número 2534
# Iteración número 2535
# Iteración número 2536
# Iteración número 2537
# Iteración número 2538
# Iteración número 2539
# Iteración número 2540
# Iteración número 2541
# Iteración número 2542
# Iteración número 2543
# Iteración número 2544
# Iteración número 2545
# Iteración número 2546
# Iteración número 2547
# Iteración número 2548
# Iteración número 2549
# Iteración número 2550
# Iteración número 2551
# Iteración número 2552
# Iteración número 2553
# Iteración número 2554
# status is 403
# status is 403
# status is 403
#
# start the 4 minute wait
# 1 minutes have passed
# 2 minutes have passed
# 3 minutes have passed
# 4 minutes have passed
# Iteración número 2555
# Iteración número 2556
# Iteración número 2557
# Iteración número 2558
# Iteración número 2559
# Iteración número 2560
# Iteración número 2561
# Iteración número 2562
# Iteración número 2563
# Iteración número 2564
# Iteración número 2565
# Iteración número 2566
# Iteración número 2567
# Iteración número 2568
# Iteración número 2569
# Iteración número 2570
# Iteración número 2571
# Iteración número 2572
# Iteración número 2573
# Iteración número 2574
# Iteración número 2575
# Iteración número 2576
# Iteración número 2577
# Iteración número 2578
# Iteración número 2579
# Iteración número 2580
# Iteración número 2581
# Iteración número 2582
# Iteración número 2583
# Iteración número 2584
# Iteración número 2585
# Iteración número 2586
# Iteración número 2587
# Iteración número 2588
# Iteración número 2589
# Iteración número 2590
# Iteración número 2591
# Iteración número 2592
# Iteración número 2593
# Iteración número 2594
# Iteración número 2595
# Iteración número 2596
# Iteración número 2597
# Iteración número 2598
# Iteración número 2599
# Iteración número 2600
# Iteración número 2601
# Iteración número 2602
# Iteración número 2603
# Iteración número 2604
# Iteración número 2605
# Iteración número 2606
# Iteración número 2607
# Iteración número 2608
# Iteración número 2609
# Iteración número 2610
# Iteración número 2611
# Iteración número 2612
# Iteración número 2613
# Iteración número 2614
# Iteración número 2615
# Iteración número 2616
# Iteración número 2617
# Iteración número 2618
# Iteración número 2619
# Iteración número 2620
# Iteración número 2621
# Iteración número 2622
# Iteración número 2623
# Iteración número 2624
# Iteración número 2625
# Iteración número 2626
# Iteración número 2627
# Iteración número 2628
# Iteración número 2629
# Iteración número 2630
# Iteración número 2631
# Iteración número 2632
# Iteración número 2633
# Iteración número 2634
# Iteración número 2635
# Iteración número 2636
# Iteración número 2637
# Iteración número 2638
# Iteración número 2639
# Iteración número 2640
# Iteración número 2641
# Iteración número 2642
# Iteración número 2643
# Iteración número 2644
# Iteración número 2645
# Iteración número 2646
# Iteración número 2647
# Iteración número 2648
# Iteración número 2649
# Iteración número 2650
# Iteración número 2651
# Iteración número 2652
# Iteración número 2653
# Iteración número 2654
# Iteración número 2655
# Iteración número 2656
# Iteración número 2657
# Iteración número 2658
# Iteración número 2659
# Iteración número 2660
# Iteración número 2661
# Iteración número 2662
# Iteración número 2663
# Iteración número 2664
# Iteración número 2665
# Iteración número 2666
# Iteración número 2667
# Iteración número 2668
# Iteración número 2669
# Iteración número 2670
# Iteración número 2671
# Iteración número 2672
# Iteración número 2673
# Iteración número 2674
# Iteración número 2675
# Iteración número 2676
# Iteración número 2677
# Iteración número 2678
# status is 403
# status is 403
# status is 403
#
# start the 4 minute wait
# 1 minutes have passed
# 2 minutes have passed
# 3 minutes have passed
# 4 minutes have passed
# Iteración número 2679
# Iteración número 2680
# Iteración número 2681
# Iteración número 2682
# Iteración número 2683
# Iteración número 2684
# Iteración número 2685
# Iteración número 2686
# Iteración número 2687
# Iteración número 2688
# Iteración número 2689
# Iteración número 2690
# Iteración número 2691
# Iteración número 2692
# Iteración número 2693
# Iteración número 2694
# Iteración número 2695
# Iteración número 2696
# Iteración número 2697
# Iteración número 2698
# Iteración número 2699
# Iteración número 2700
